# %%
# %run logger.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\Desktop\DAQ_DataLogger\logger.py:18
#      15 import time
#      17 # Configure NI DAQmx settings
# ---> 18 task = nidaqmx.Task()
#      19 task.ai_channels.add_ai_voltage_chan("Dev1/ai0", terminal_config=TerminalConfiguration.RSE)
#      20 task.timing.cfg_samp_clk_timing(rate=1000, sample_mode=AcquisitionType.CONTINUOUS)
#
# File E:\miniconda3\Lib\site-packages\nidaqmx\task.py:92, in Task.__init__(self, new_task_name, grpc_options)
#      86     raise DaqError(
#      87         f'Unsupported session name: "{grpc_options.session_name}". If a session name is specified, it must match the task name.',
#      88         DAQmxErrors.UNKNOWN,
#      89         task_name=new_task_name)
#      91 self._interpreter = utils._select_interpreter(grpc_options)
# ...
